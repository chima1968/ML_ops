# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn import model_selection

# %%
cols=['flength','fwidth','fsize','fconc','fconc1','fAsym','fM3Long','fN3Trans','fAlpha','fdist','fclass']
df=pd.read_csv('D:/HALDEN/downloads/magic04.data',names=cols)
df
# Out:
#         flength    fwidth   fsize   fconc  fconc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fN3Trans   fAlpha     fdist fclass
# 0       -8.2027  40.0920   81.8828      g
# ...

# %%
df['fclass']=(df['fclass'] == 'g').astype(int)
df
# Out:
#         flength    fwidth   fsize   fconc  fconc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fN3Trans   fAlpha     fdist  fclass
# 0       -8.2027  40.0920   81.8828       1
# ...

# %%
import matplotlib.pyplot as plt
for label in cols[:-1]:
    plt.hist(df[df['fclass']==1][label],color='blue',label='gamma',alpha=0.7,density=True)
    plt.hist(df[df['fclass']==0][label],color='red',label='hadron',alpha=0.7,density=True)
    plt.title(label)
    plt.ylabel('probability')
    plt.xlabel(label)
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\vscode\python files\machine learning tutorials.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/vscode/python%20files/machine%20learning%20tutorials.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/d%3A/vscode/python%20files/machine%20learning%20tutorials.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> for label in cols[:-1]:
#       <a href='vscode-notebook-cell:/d%3A/vscode/python%20files/machine%20learning%20tutorials.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     plt.hist(df[df['fclass']==1][label],color='blue',label='gamma',alpha=0.7,density=True)
# ...

# %% [markdown]
# Train ,validation and test datasets

# %%
Train,validate,test=np.split(df.sample(frac=1),[int(0.6*len(df)), int(0.8*len(df))])

# %%
def scale_dataset(dataframe):
    x=dataframe[dataframe.cols[:-1]].values
    y=dataframe[dataframe.cols[-1]].values
    
    
    scaler=StandardScaler()
    x=scaler.fit_transform(x)
    
    data=np.hstack((x,np.reshape(y,np.reshape(y,(-1,1)))))
    
    return data ,x,y

# %%
Train,validate,test=np.split(df.sample(frac=1),[int(0.6*len(df)), int(0.8*len(df))])
print(len(Train[Train['fclass']==1]))
print(len(Train[Train['fclass']==0]))
# Out:
# 7469
# 3943

# %%
knn=KNeighborsClassifier(n_neighbors=5,algorithm='brute')

# %%
x_train,x_test,y_train,y_test=model_selection.train_test_split(trans)
